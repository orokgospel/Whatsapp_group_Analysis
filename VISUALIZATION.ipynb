# %% [markdown]
# # VISUALIZED REPORT

# %% [markdown]
# **The total message showing activities on group for the period of June to July 2022:**       $1533$ <br>
# **Number of Media Shared:**       $48$<br>
# **Number of Emojis Shared:**       $93511$ <br>
# **Number of Links Shared:**       $22$

# %% [markdown]
# ![newplot%20%281%29.png](attachment:newplot%20%281%29.png)

# %% [markdown]
# <h2>Community progression Chart within the period of June-July 2022</h2>
#
# ![prochar.png](attachment:prochar.png)

# %% [markdown]
# ![ci2.png](attachment:ci2.png)

# %% [markdown]
# There are **:** $94534$ Words in all the messages.

# %% [markdown]
# # Generate a word cloud image:

# %% [markdown]
# The overall or general Word Cloud Image
# ![genntk.png](attachment:genntk.png)

# %% [markdown]
# # Now let’s have a look at the most used words by each person by visualizing two different word clouds:

# %% [markdown]
# **Author Name:** <h2>Emmanuel Boniface  </h2>
#
# ![emm.png](attachment:emm.png)

# %% [markdown]
# **Author Name:** <h2>Oshimua Victor</h2>
#
# ![victor.png](attachment:victor.png)

# %% [markdown]
# **Author Name:** <h2>Florence O.</h2>
#
# ![flor.png](attachment:flor.png)

# %% [markdown]
# **Author Name:** <h2>Tochi </h2>
#
# ![tochi.png](attachment:tochi.png)

# %% [markdown]
# **Author Name:** <h2>Evans</h2>
#
# ![evans.png](attachment:evans.png)

# %% [markdown]
# **Author Name:** <h2>Jacia</h2>
#
# ![jacia.png](attachment:jacia.png)

# %% [markdown]
# # Sentiment Score:
#      😊
#
#
#    # +-ve

# %% [markdown]
# ![newplot%20%283%29.png](attachment:newplot%20%283%29.png)

# %% [markdown]
# **So, the data I used indicates that most of the messages between members in the group are more of Neutral. Which means it’s neither positive nor negative.**

# %% [markdown]
# <h2> <b>Summary:<br></h2>
# So this is how we can easily analyze any WhatsApp chat between you and your friend, customer, or even a group of people.<br> This data can be used for many other tasks of natural language processing.
